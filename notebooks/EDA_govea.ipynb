# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../data/data_globant.csv')

# %%
data.head()
# Out:
#       Date                            Email             Name  \
# 0  02Jan23  natalia.ramirez@tec.globant.com  Natalia Ramírez
# 1  03Jan23  natalia.ramirez@tec.globant.com  Natalia Ramírez
# 2  04Jan23  natalia.ramirez@tec.globant.com  Natalia Ramírez
# 3  05Jan23  natalia.ramirez@tec.globant.com  Natalia Ramírez
# 4  06Jan23  natalia.ramirez@tec.globant.com  Natalia Ramírez
#
#              Position Seniority    Location       Studio  \
# 0  Software Developer        Jr  CO/ANT/MED  Engineering
# 1  Software Developer        Jr  CO/ANT/MED  Engineering
# 2  Software Developer        Jr  CO/ANT/MED  Engineering
# 3  Software Developer        Jr  CO/ANT/MED  Engineering
# 4  Software Developer        Jr  CO/ANT/MED  Engineering
#
#                   Client Client Tag           Project Project Tag  \
# 0  GreenWave Innovations     GWI001  Atlas Initiative      ATLINT
# 1  GreenWave Innovations     GWI001  Atlas Initiative      ATLINT
# ...

# %%
len(data['Name'].unique())
# Out:
# 94

# %%
data['Engagement'].notnull().sum()
# Out:
# np.int64(11366)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11366 entries, 0 to 11365
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          11366 non-null  object
#  1   Email         11366 non-null  object
#  2   Name          11366 non-null  object
#  3   Position      11366 non-null  object
#  4   Seniority     11366 non-null  object
#  5   Location      11366 non-null  object
#  6   Studio        11366 non-null  object
#  7   Client        11366 non-null  object
#  8   Client Tag    11366 non-null  object
#  9   Project       11366 non-null  object
#  10  Project Tag   11366 non-null  object
#  11  Team Name     11366 non-null  object
#  12  Engagement    11366 non-null  float64
#  13  Email Leader  10226 non-null  object
#  14  Year          11366 non-null  int64
#  15  Month         11366 non-null  int64
#  16  Day           11366 non-null  int64
# dtypes: float64(1), int64(3), object(13)
# ...

# %%
data[data['Email Leader'].isnull()]
# Out:
#           Date                          Email           Name         Position  \
# 1049   02Jan23     laura.leon@tec.globant.com     Laura León  Project Manager
# 1050   03Jan23     laura.leon@tec.globant.com     Laura León  Project Manager
# 1051   04Jan23     laura.leon@tec.globant.com     Laura León  Project Manager
# 1052   05Jan23     laura.leon@tec.globant.com     Laura León  Project Manager
# 1053   06Jan23     laura.leon@tec.globant.com     Laura León  Project Manager
# ...        ...                            ...            ...              ...
# 10988  05Apr23  carlos.ortega@tec.globant.com  Carlos Ortega  Project Manager
# 10989  06Apr23  carlos.ortega@tec.globant.com  Carlos Ortega  Project Manager
# 10990  10Apr23  carlos.ortega@tec.globant.com  Carlos Ortega  Project Manager
# 10991  11Apr23  carlos.ortega@tec.globant.com  Carlos Ortega  Project Manager
# 10992  12Apr23  carlos.ortega@tec.globant.com  Carlos Ortega  Project Manager
#
# ...

# %% [markdown]
# ### null email leader

# %%
data[data['Email Leader'].isnull()]['Project'].unique()
# Out:
# array(['Atlas Initiative', 'Echo System', 'Horizon Expansion',
#        'Nexus Development', 'Odyssey Quest', 'Catalyst Program',
#        'Vanguard Initiative', 'Serenity Project'], dtype=object)

# %%
data[data['Email Leader'].notnull()]['Project'].unique()
# Out:
# array(['Atlas Initiative', 'Echo System', 'Horizon Expansion',
#        'Nexus Development', 'Catalyst Program', 'Odyssey Quest',
#        'Serenity Project', 'Vanguard Initiative'], dtype=object)

# %%
data[data['Email Leader'].isnull()]['Studio'].unique()
# Out:
# array(['Delivery', 'Engineering', 'Quality Engineering', 'Product'],
#       dtype=object)

# %%
data[data['Email Leader'].notnull()]['Studio'].unique()
# Out:
# array(['Engineering', 'Product', 'Quality Engineering', 'Cloud Ops',
#        'Data', 'Design'], dtype=object)

# %%
comb_null = data[data['Email Leader'].isnull()][['Studio', 'Project Tag', 'Position']].drop_duplicates()

# %%
comb_null
# Out:
#                     Studio Project Tag                  Position
# 1049              Delivery      ATLINT           Project Manager
# 1179           Engineering      ECOSYS       Solutions Architect
# 1251   Quality Engineering      ECOSYS  Quality Assurance Tester
# 1299               Product      ECOSYS             Product Owner
# 2314              Delivery      HOREXP           Project Manager
# 3070           Engineering      NEXDEV     Technology Consultant
# 4209              Delivery      ODYQST           Project Manager
# 4555              Delivery      CATPRO           Project Manager
# 7590              Delivery      VGRDIN           Project Manager
# 8344              Delivery      NEXDEV           Project Manager
# 10813             Delivery      STYPRJ           Project Manager

# %%
comb_notnull = data[data['Email Leader'].notnull()][['Studio', 'Project Tag', 'Position']].drop_duplicates()

# %%
comb_notnull
# Out:
#                     Studio Project Tag                  Position
# 0              Engineering      ATLINT        Software Developer
# 251                Product      ATLINT          Business Analyst
# 386    Quality Engineering      ATLINT  Quality Assurance Tester
# 1305               Product      ECOSYS             Product Owner
# 1431   Quality Engineering      ECOSYS  Quality Assurance Tester
# 1557           Engineering      ECOSYS        Software Developer
# 2062   Quality Engineering      HOREXP  Test Automation Engineer
# 2188           Engineering      HOREXP       Solutions Architect
# 2440             Cloud Ops      HOREXP           DevOps Engineer
# 2566             Cloud Ops      HOREXP  Cybersecurity Specialist
# 3198           Engineering      NEXDEV        Software Developer
# 3319               Product      NEXDEV          Business Analyst
# 3445   Quality Engineering      NEXDEV  Test Automation Engineer
# ...

# %%
df_join = comb_null.merge(comb_notnull, how='inner')

# %%
df_join
# Out:
#                 Studio Project Tag                  Position
# 0  Quality Engineering      ECOSYS  Quality Assurance Tester
# 1              Product      ECOSYS             Product Owner

# %%
data[data['Studio'] == 'Quality Engineering'][data['Position'] == 'Quality Assurance Tester'][data['Project Tag'] == 'ECOSYS']
# Out:
# /var/folders/0p/v_8rs5px14l8lggm7z70s1dw0000gn/T/ipykernel_99414/656581636.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data['Studio'] == 'Quality Engineering'][data['Position'] == 'Quality Assurance Tester'][data['Project Tag'] == 'ECOSYS']
# /var/folders/0p/v_8rs5px14l8lggm7z70s1dw0000gn/T/ipykernel_99414/656581636.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data['Studio'] == 'Quality Engineering'][data['Position'] == 'Quality Assurance Tester'][data['Project Tag'] == 'ECOSYS']
#          Date                            Email             Name  \
# 1251  17Apr23   cristian.bravo@tec.globant.com   Cristian Bravo
# 1252  18Apr23   cristian.bravo@tec.globant.com   Cristian Bravo
# 1253  19Apr23   cristian.bravo@tec.globant.com   Cristian Bravo
# 1254  20Apr23   cristian.bravo@tec.globant.com   Cristian Bravo
# 1255  21Apr23   cristian.bravo@tec.globant.com   Cristian Bravo
# ...
