# %%
import pandas as pd

# %%
df = pd.read_csv('../outputs/csv/final_top_bottom_segments.csv')

# %%
df
# Out:
#    Project Tag   Seniority  n_registros  prob_mejorar  prob_empeorar  \
# 0       CATPRO  Sr Level 3          126      0.348019       0.082081
# 1       ODYQST          Jr          126      0.443062       0.046697
# 2       HOREXP  Sr Level 3          124      0.346429       0.153848
# 3       ECOSYS  Sr Level 1          126      0.257407       0.177778
# 4       ECOSYS          Jr          123      0.244196       0.078048
# 5       HOREXP          Jr          126      0.115455       0.080505
# 6       VGRDIN  Sr Level 2          246      0.198926       0.425889
# 7       ATLINT         Ssr          742      0.117321       0.281010
# 8       ECOSYS         Ssr          246      0.202601       0.207222
# 9       ODYQST         Ssr          252      0.075387       0.137151
# 10      CATPRO  Sr Level 2          147      0.279304       0.158018
# 11      CATPRO  Sr Level 1           68      0.000000       0.002985
# 12      HOREXP  Sr Level 1          126      0.100000       0.103670
# ...

# %%
df_alto = df
